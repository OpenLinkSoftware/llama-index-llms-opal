# %% [markdown]
# Install necessary packages:
#
# ```
# pip install llama-index
# pip install git+https://github.com/OpenLinkSoftware/llama-index-llms-opal.git
# ```

# %%
! pip install --upgrade git+https://github.com/OpenLinkSoftware/llama-index-llms-opal.git
! pip install llama-index>=0.10.55

# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-xxxxxxxxxxxxxxxxxx"
os.environ["OPENLINK_API_KEY"] = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

from llama_index_opal import OPAL_Assistant

# Virtuoso Help assistant
assistand_id = "asst_CIx4iIZsFh0eXJuUdvPkknai"
llm = OPAL_Assistant(
    assistant_id=assistand_id,
    temperature=0.2,
    top_p=0.5,
    continue_thread=True
    )

resp = llm.complete("How to install Virtuoso DBMS on Linux")
print(resp)
# Out:
# Installing Virtuoso Open Source Edition (VOS) on a Linux system can be done through several methods, including compiling from source, using pre-built packages, or using Docker. Below, I'll guide you through the process for each method.
#
# ### Method 1: Installing from Pre-built Packages
#
# 1. **Update Your Package Manager**
#    Open a terminal and run the following command to update your package manager:
#    ```bash
#    sudo apt-get update
#    ```
#
# 2. **Install Virtuoso**
#    If you are using a Debian-based distribution (like Ubuntu), you can install Virtuoso using `apt-get`:
#    ```bash
#    sudo apt-get install virtuoso-opensource
#    ```
#
#    For other distributions, check if Virtuoso is available in the respective package manager or proceed to compile from source.
#
# ### Method 2: Compiling from Source
#
# 1. **Install Dependencies**
#    Before compiling Virtuoso, you need to install some dependencies. For Ubuntu/Debian:
#    ```bash
#    sudo apt-get install autoconf automake libtool flex bison gperf gawk m4 make openssl libssl-dev libreadline-dev
#    ```
#
# 2. **Clone the Repository**
#    Clone the Virtuoso repository from GitHub:
#    ```bash
#    git clone https://github.com/openlink/virtuoso-opensource.git
#    cd virtuoso-opensource
#    ```
#
# 3. **Configure the Build**
#    Prepare the build environment:
#    ```bash
#    ./autogen.sh
#    ```
#
#    Configure the makefile:
#    ```bash
#    ./configure
#    ```
#
# 4. **Compile and Install**
#    Compile and install Virtuoso:
#    ```bash
#    make
#    sudo make install
#    ```
#
# ### Method 3: Using Docker
#
# 1. **Install Docker**
#    If Docker is not installed on your system, install it by following the official Docker installation guide for your Linux distribution.
#
# 2. **Run Virtuoso using Docker**
#    You can run Virtuoso using a Docker image:
#    ```bash
#    docker run -p 8890:8890 -p 1111:1111 -e DBA_PASSWORD=dba_pwd -d tenforce/virtuoso
#    ```
#
#    Replace `dba_pwd` with your desired DBA password.
#
# ### Post-Installation
#
# - **Start the Virtuoso Server**
#   Depending on your installation method, you might start Virtuoso using:
#   ```bash
#   virtuoso-t +foreground
#   ```
#
# - **Access Virtuoso Conductor**
#   Open a web browser and navigate to `http://localhost:8890/conductor` to access the Virtuoso Conductor interface. Use the DBA account to log in.
#
# - **Configuration and Tuning**
#   You might want to configure and tune your Virtuoso instance by editing the `virtuoso.ini` file, typically found in the installation directory.
#
# These steps should help you get Virtuoso up and running on your Linux system. If you encounter any issues, checking the official Virtuoso documentation or their community forums can be very helpful.

# %%
# it will continue llm session above, because we used parameter   continue_chat=True
resp = llm.complete("How to install Virtuoso DBMS on Windows")
print(resp)
# Out:
# Installing Virtuoso Open Source Edition (VOS) on a Windows system can be done by downloading and running the pre-built binaries or by compiling from source. Here’s a step-by-step guide for both methods:
#
# ### Method 1: Installing from Pre-built Binaries
#
# 1. **Download the Installer**
#    - Visit the official [GitHub repository of Virtuoso](https://github.com/openlink/virtuoso-opensource/releases) or the [OpenLink Downloads page](http://vos.openlinksw.com/owiki/wiki/VOS/VOSDownload) to download the latest stable release of Virtuoso for Windows.
#
# 2. **Run the Installer**
#    - Locate the downloaded `.exe` file and double-click it to start the installation process.
#    - Follow the on-screen instructions to install Virtuoso. This typically involves choosing an installation directory and configuring initial settings.
#
# 3. **Start Virtuoso**
#    - After installation, you can start the Virtuoso server using the Virtuoso Service Manager, which can be found in the Start Menu under the Virtuoso folder.
#    - Alternatively, you can start Virtuoso from the command line by navigating to the installation directory and running:
#      ```bash
#      virtuoso-t +foreground
#      ```
#
# ### Method 2: Compiling from Source
#
# 1. **Install Required Tools**
#    - Install Visual Studio or another C/C++ compiler that supports building Windows applications.
#    - Install Git to clone the repository.
#
# 2. **Clone the Repository**
#    - Open a command prompt or PowerShell and run:
#      ```bash
#      git clone https://github.com/openlink/virtuoso-opensource.git
#      cd virtuoso-opensource
#      ```
#
# 3. **Prepare the Build Environment**
#    - Open the Visual Studio Command Prompt (ensure it matches the architecture you wish to build for, e.g., x64).
#    - Navigate to the directory where you cloned Virtuoso.
#
# 4. **Build Virtuoso**
#    - Run the build commands:
#      ```bash
#      build.bat
#      ```
#    - This script should configure and compile Virtuoso. If there are errors, you might need to resolve dependencies or configuration issues.
#
# 5. **Install the Compiled Binaries**
#    - After building, binaries will be located in the `bin` directory of your build folder. You can run Virtuoso directly from here or move the binaries to a more permanent location.
#
# ### Post-Installation
#
# - **Access Virtuoso Conductor**
#   - Open a web browser and navigate to `http://localhost:8890/conductor` to access the Virtuoso Conductor interface. The default username and password are usually "dba".
#
# - **Configuration**
#   - You might want to configure your Virtuoso instance for better performance or security by editing the `virtuoso.ini` file, which is typically found in the installation directory.
#
# - **Firewall Settings**
#   - Ensure that Windows Firewall or any other firewall software is configured to allow traffic on the ports Virtuoso uses (default is 8890 for HTTP and 1111 for the admin interface).
#
# These steps should help you install Virtuoso on a Windows system. If you encounter any issues, the Virtuoso forums and official documentation are good resources for troubleshooting.
